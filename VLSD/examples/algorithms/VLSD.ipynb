# %% [markdown]
# # Example of using the VLSD algorithm

# %% [markdown]
# ## About this document
#
# The purpose of this document is to show an example of using the VLSD algorithm.
#
# In the following sections, an introduction of the this algorithm will be presented, followed by instructions to install the `subgroups` library. Then, the execution process of the VLSD algorithm will be described, including the necessary steps to consider. Finally, the results obtained from the application of this algorithm will be presented, highlighting the information obtained in the output file and the one that can be accessed through the model properties.

# %% [markdown]
# ## VLSD algorithm

# %% [markdown]
# VLSD (Vertical List Subgroup Discovery) [[1]](#1) is a subgroup discovery algorithm that combines an equivalence class exploration strategy and a pruning strategy based on optimistic estimate, and that is based on the vertical list data structure.

# %% [markdown]
# ## Installing the `subgroups` library
#
# To install the `subgroups` library, you have to execute the following cell:

# %%
# !pip install subgroups
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting subgroups
#   Downloading subgroups-0.1.6-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 KB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from subgroups) (0.14.0)
# Requirement already satisfied: pandas>=2.0.3 in /home/dionnegantzert/.local/lib/python3.10/site-packages (from subgroups) (2.2.2)
# Requirement already satisfied: bitarray>=2.7.6 in /home/dionnegantzert/.local/lib/python3.10/site-packages (from subgroups) (2.8.1)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->subgroups) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->subgroups) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=2.0.3->subgroups) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->subgroups) (2023.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /home/dionnegantzert/.local/lib/python3.10/site-packages (from statsmodels>=0.14.0->subgroups) (1.12.0)
# Requirement already satisfied: packaging>=21.3 in /usr/lib/python3/dist-packages (from statsmodels>=0.14.0->subgroups) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.14.0->subgroups) (0.5.3)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.2->statsmodels>=0.14.0->subgroups) (1.16.0)
# Installing collected packages: subgroups
# Successfully installed subgroups-0.1.6

# %% [markdown]
# After that, to verify that the installation was successful, yo can run the following cell:

# %%
import subgroups.tests as st
st.run_all_tests()
# Out:
# test_Operator_evaluate_method (tests.core.test_operator.TestOperator) ... ok
# test_Operator_evaluate_method_with_pandasSeries (tests.core.test_operator.TestOperator) ... ok
# test_Operator_generate_from_str_method (tests.core.test_operator.TestOperator) ... ok
# test_Operator_string_representation (tests.core.test_operator.TestOperator) ... ok
# test_Pattern_contains_method (tests.core.test_pattern.TestPattern) ... ok
# test_Pattern_general (tests.core.test_pattern.TestPattern) ... ok
# test_Pattern_is_contained_method (tests.core.test_pattern.TestPattern) ... ok
# test_Pattern_is_refinement_method (tests.core.test_pattern.TestPattern) ... ok
# test_Selector_attributes (tests.core.test_selector.TestSelector) ... ok
# test_Selector_comparisons (tests.core.test_selector.TestSelector) ... ok
# test_Selector_creation_process (tests.core.test_selector.TestSelector) ... ok
# test_Selector_deletion_process (tests.core.test_selector.TestSelector) ... ok
# test_Selector_generate_from_str_method (tests.core.test_selector.TestSelector) ... ok
# test_Selector_match_method (tests.core.test_selector.TestSelector) ... ok
# test_Selector_same_value_different_type (tests.core.test_selector.TestSelector) ... ok
# test_Subgroup_filter (tests.core.test_subgroup.TestSubgroup) ... ok
# test_Subgroup_general (tests.core.test_subgroup.TestSubgroup) ... ok
# test_Subgroup_is_refinement_method (tests.core.test_subgroup.TestSubgroup) ... ok
#
# ----------------------------------------------------------------------
# Ran 18 tests in 0.044s
#
# OK
# test_quality_measures_compute (tests.quality_measures.test_quality_measures.TestQualityMeasures) ... ok
# test_quality_measures_general (tests.quality_measures.test_quality_measures.TestQualityMeasures) ... ok
# test_quality_measures_value_of_class_variables (tests.quality_measures.test_quality_measures.TestQualityMeasures) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.004s
#
# OK
# test_FPTreeForSDMap_build_tree_1 (tests.data_structures.test_fp_tree_for_sdmap.TestFPTreeForSDMap) ... /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# ok
# test_FPTreeForSDMap_build_tree_2 (tests.data_structures.test_fp_tree_for_sdmap.TestFPTreeForSDMap) ... /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# ok
# test_FPTreeForSDMap_build_tree_3 (tests.data_structures.test_fp_tree_for_sdmap.TestFPTreeForSDMap) ... /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# ok
# test_FPTreeForSDMap_build_tree_4 (tests.data_structures.test_fp_tree_for_sdmap.TestFPTreeForSDMap) ... /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# ok
# test_FPTreeForSDMap_generate_conditional_fp_tree_1 (tests.data_structures.test_fp_tree_for_sdmap.TestFPTreeForSDMap) ... ok
# test_FPTreeForSDMap_generate_conditional_fp_tree_2 (tests.data_structures.test_fp_tree_for_sdmap.TestFPTreeForSDMap) ... ok
# test_FPTreeForSDMap_generate_set_of_frequent_selectors_1 (tests.data_structures.test_fp_tree_for_sdmap.TestFPTreeForSDMap) ...
# ##################################
# ########## CORE PACKAGE ##########
# ##################################
#
#
# ##############################################
# ########## QUALITY MEASURES PACKAGE ##########
# ##############################################
#
#
# #############################################
# ########## DATA STRUCTURES PACKAGE ##########
# #############################################
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# ok
# test_FPTreeForSDMap_generate_set_of_frequent_selectors_2 (tests.data_structures.test_fp_tree_for_sdmap.TestFPTreeForSDMap) ... /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# ok
# test_FPTreeForSDMap_generate_set_of_frequent_selectors_3 (tests.data_structures.test_fp_tree_for_sdmap.TestFPTreeForSDMap) ... ok
# test_FPTreeNode_general (tests.data_structures.test_fp_tree_node.TestFPTreeNode) ... ok
# test_subgroup_list_1 (tests.data_structures.test_subgroup_list.TestSubgroupList) ... ok
# test_subgroup_list_2 (tests.data_structures.test_subgroup_list.TestSubgroupList) ... ok
# test_subgroup_list_3 (tests.data_structures.test_subgroup_list.TestSubgroupList) ... ok
# test_subgroup_list_4 (tests.data_structures.test_subgroup_list.TestSubgroupList) ... ok
# test_vertical_list_1 (tests.data_structures.test_vertical_list_with_bitsets.TestVerticalListWithBitsets) ... ok
# test_vertical_list_2 (tests.data_structures.test_vertical_list_with_bitsets.TestVerticalListWithBitsets) ... ok
# test_vertical_list_3 (tests.data_structures.test_vertical_list_with_bitsets.TestVerticalListWithBitsets) ... ok
# test_vertical_list_str_method (tests.data_structures.test_vertical_list_with_bitsets.TestVerticalListWithBitsets) ... ok
# test_vertical_list_1 (tests.data_structures.test_vertical_list_with_sets.TestVerticalListWithSets) ... ok
# test_vertical_list_2 (tests.data_structures.test_vertical_list_with_sets.TestVerticalListWithSets) ... ok
# test_vertical_list_3 (tests.data_structures.test_vertical_list_with_sets.TestVerticalListWithSets) ... ok
# test_vertical_list_str_method (tests.data_structures.test_vertical_list_with_sets.TestVerticalListWithSets) ... ok
#
# ----------------------------------------------------------------------
# Ran 22 tests in 0.195s
#
# OK
# test_DSLM_compute_overlap_factor_function_1 (tests.algorithms.subgroup_lists.test_dslm.TestDSLM) ... ok
# test_DSLM_compute_overlap_factor_function_2 (tests.algorithms.subgroup_lists.test_dslm.TestDSLM) ... ok
# test_DSLM_compute_overlap_factor_function_3 (tests.algorithms.subgroup_lists.test_dslm.TestDSLM) ... ok
# test_DSLM_counter_of_subgroups_1 (tests.algorithms.subgroup_lists.test_dslm.TestDSLM) ... ok
# test_DSLM_counter_of_subgroups_2 (tests.algorithms.subgroup_lists.test_dslm.TestDSLM) ... ok
# test_GMSL_fit_method_1 (tests.algorithms.subgroup_lists.test_gmsl.TestGMSL) ... ok
# test_GMSL_load_candidates_method_1 (tests.algorithms.subgroup_lists.test_gmsl.TestGMSL) ... ok
# test_GMSL_load_candidates_method_2 (tests.algorithms.subgroup_lists.test_gmsl.TestGMSL) ... ok
# test_GMSL_load_candidates_method_3 (tests.algorithms.subgroup_lists.test_gmsl.TestGMSL) ... ok
# test_GMSL_load_candidates_method_4 (tests.algorithms.subgroup_lists.test_gmsl.TestGMSL) ... ok
# test_GMSL_load_candidates_method_5 (tests.algorithms.subgroup_lists.test_gmsl.TestGMSL) ... ok
# test_GMSL_mdl_functions_1 (tests.algorithms.subgroup_lists.test_gmsl.TestGMSL) ... ok
# test_GMSL_mdl_functions_2 (tests.algorithms.subgroup_lists.test_gmsl.TestGMSL) ... ok
# test_GMSL_mdl_functions_3 (tests.algorithms.subgroup_lists.test_gmsl.TestGMSL) ...
# ########################################
# ########## ALGORITHMS PACKAGE ##########
# ########################################
# ok
# test_BSD_cardinality (tests.algorithms.subgroup_sets.test_bsd.TestBSD) ... ok
# test_BSD_checkRel (tests.algorithms.subgroup_sets.test_bsd.TestBSD) ... ok
# test_BSD_checkRelevancies (tests.algorithms.subgroup_sets.test_bsd.TestBSD) ... ok
# test_BSD_fit1 (tests.algorithms.subgroup_sets.test_bsd.TestBSD) ... ok
# test_BSD_fit2 (tests.algorithms.subgroup_sets.test_bsd.TestBSD) ... ok
# test_BSD_fit3 (tests.algorithms.subgroup_sets.test_bsd.TestBSD) ... ok
# test_BSD_fit4 (tests.algorithms.subgroup_sets.test_bsd.TestBSD) ... ok
# test_BSD_init_method (tests.algorithms.subgroup_sets.test_bsd.TestBSD) ... ok
# test_BSD_logicalAnd (tests.algorithms.subgroup_sets.test_bsd.TestBSD) ... ok
# test_CBSD_checkRel (tests.algorithms.subgroup_sets.test_cbsd.TestCBSD) ... ok
# test_CBSD_checkRelevancies (tests.algorithms.subgroup_sets.test_cbsd.TestCBSD) ... ok
# test_CBSD_fit1 (tests.algorithms.subgroup_sets.test_cbsd.TestCBSD) ... ok
# test_CBSD_fit2 (tests.algorithms.subgroup_sets.test_cbsd.TestCBSD) ... ok
# test_CBSD_fit3 (tests.algorithms.subgroup_sets.test_cbsd.TestCBSD) ... ok
# test_CBSD_fit4 (tests.algorithms.subgroup_sets.test_cbsd.TestCBSD) ... ok
# test_CBSD_init_method (tests.algorithms.subgroup_sets.test_cbsd.TestCBSD) ... ok
# test_CPBSD_checkRel (tests.algorithms.subgroup_sets.test_cpbsd.TestCPBSD) ... ok
# test_CPBSD_checkRelevancies (tests.algorithms.subgroup_sets.test_cpbsd.TestCPBSD) ... ok
# test_CPBSD_fit1 (tests.algorithms.subgroup_sets.test_cpbsd.TestCPBSD) ... ok
# test_CPBSD_fit2 (tests.algorithms.subgroup_sets.test_cpbsd.TestCPBSD) ... ok
# test_CPBSD_fit3 (tests.algorithms.subgroup_sets.test_cpbsd.TestCPBSD) ... ok
# test_CPBSD_fit4 (tests.algorithms.subgroup_sets.test_cpbsd.TestCPBSD) ... ok
# test_CPBSD_init_method (tests.algorithms.subgroup_sets.test_cpbsd.TestCPBSD) ... ok
# test_QFinder_fit (tests.algorithms.subgroup_sets.test_qfinder.TestQFinder) ... /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_values[pattern] = results.pvalues[0]
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/bitset_qfinder.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   odds_ratios[pattern] = np.exp(results.params[0])
# ...
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:134: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# ok
# test_SDMapStar_unselected_and_selected_subgroups_2 (tests.algorithms.subgroup_sets.test_sdmapstar.TestSDMapStar) ... /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# /home/dionnegantzert/.local/lib/python3.10/site-packages/subgroups/data_structures/fp_tree_for_sdmap.py:156: FutureWarning: The provided callable <function sum at 0x7c0baa198790> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tp_and_fp_for_each_value = target_attribute_as_a_mask.groupby(current_Series).aggregate([size, sum]) # tp -> sum; fp -> size - sum; n -> size.
# ok
# test_VLSD_additional_parameters_in_fit_method (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
# test_VLSD_fit_method_1 (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
# test_VLSD_fit_method_2 (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
# test_VLSD_fit_method_3 (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
# test_VLSD_fit_method_4 (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
# test_VLSD_fit_method_5 (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
# test_VLSD_fit_method_6 (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
# test_VLSD_fit_method_7 (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
# test_VLSD_init_method_1 (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
# test_VLSD_init_method_2 (tests.algorithms.subgroup_sets.test_vlsd.TestVLSD) ... ok
#
# ----------------------------------------------------------------------
# Ran 91 tests in 2.263s
#
# OK
# test_dataframe_filters_general (tests.utils.test_dataframe_filters.TestDataFrameFilter) ... ok
# test_to_input_format_for_subgroup_list_algorithms_1 (tests.utils.test_file_format_transformations.TestToInputFormatForSubgroupListAlgorithms) ... ok
# test_to_input_format_for_subgroup_list_algorithms_2 (tests.utils.test_file_format_transformations.TestToInputFormatForSubgroupListAlgorithms) ... ok
# test_to_input_format_for_subgroup_list_algorithms_3 (tests.utils.test_file_format_transformations.TestToInputFormatForSubgroupListAlgorithms) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.017s
#
# OK
# ###################################
# ########## UTILS PACKAGE ##########
# ###################################

# %% [markdown]
# ## Running the VLSD algorithm
#
# To run the VLSD algorithm on a dataset, it is necessary to follow these steps:
#
# - Load the dataset into a Pandas `DataFrame` object.
# - Set the target, which must be a tuple of the form (column_name, value).
# - Select the quality measure and optimistic estimate to use.
# - Create the VLSD model with the desired parameters and run it.

# %% [markdown]
# The following is an example of running this algorithm on a dataset:

# %%
import pandas as pd
from subgroups.quality_measures import WRAcc
from subgroups.quality_measures import WRAccOptimisticEstimate1
from subgroups.algorithms import VLSD

dataset = pd.DataFrame({'att1': ['v3', 'v2', 'v1'], 'att2': ['v1', 'v2', 'v3'], 'att3': ['v2', 'v1', 'v1'], 'class': ['no', 'yes', 'no']})
target = ('class', 'yes')

model = VLSD(quality_measure = WRAcc(), q_minimum_threshold  = -1, optimistic_estimate = WRAccOptimisticEstimate1(), oe_minimum_threshold = -1, sort_criterion_in_s1 = VLSD.SORT_CRITERION_NO_ORDER, sort_criterion_in_other_sizes = VLSD.SORT_CRITERION_NO_ORDER, vertical_lists_implementation = VLSD.VERTICAL_LISTS_WITH_BITSETS, write_results_in_file = True, file_path = "./results.txt")
model.fit(dataset, target)

# %% [markdown]
# ## Results
#
# Running the following cell, we get the subgroups obtained by the algorithm:

# %%
with open("./results.txt", "r") as file:
    for current_line in file:
        print(current_line.strip())
# Out:
# Description: [att1 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('001') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att1 = 'v2'], Target: class = 'yes' ; Sequence of instances tp = bitarray('010') ; Sequence of instances fp = bitarray('000') ; Quality Measure WRAcc = 0.22222222222222224 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.6666666666666667 ; tp = 1 ; fp = 0 ; TP = 1 ; FP = 2
# Description: [att1 = 'v3'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('100') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att2 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('100') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att2 = 'v2'], Target: class = 'yes' ; Sequence of instances tp = bitarray('010') ; Sequence of instances fp = bitarray('000') ; Quality Measure WRAcc = 0.22222222222222224 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.6666666666666667 ; tp = 1 ; fp = 0 ; TP = 1 ; FP = 2
# Description: [att2 = 'v3'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('001') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att3 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('010') ; Sequence of instances fp = bitarray('001') ; Quality Measure WRAcc = 0.11111111111111112 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.33333333333333337 ; tp = 1 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att3 = 'v2'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('100') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att1 = 'v1', att2 = 'v3'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('001') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att1 = 'v1', att3 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('001') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att1 = 'v1', att2 = 'v3', att3 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('001') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att1 = 'v2', att2 = 'v2'], Target: class = 'yes' ; Sequence of instances tp = bitarray('010') ; Sequence of instances fp = bitarray('000') ; Quality Measure WRAcc = 0.22222222222222224 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.6666666666666667 ; tp = 1 ; fp = 0 ; TP = 1 ; FP = 2
# Description: [att1 = 'v2', att3 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('010') ; Sequence of instances fp = bitarray('000') ; Quality Measure WRAcc = 0.22222222222222224 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.6666666666666667 ; tp = 1 ; fp = 0 ; TP = 1 ; FP = 2
# Description: [att1 = 'v2', att2 = 'v2', att3 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('010') ; Sequence of instances fp = bitarray('000') ; Quality Measure WRAcc = 0.22222222222222224 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.6666666666666667 ; tp = 1 ; fp = 0 ; TP = 1 ; FP = 2
# Description: [att1 = 'v3', att2 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('100') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att1 = 'v3', att3 = 'v2'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('100') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att1 = 'v3', att2 = 'v1', att3 = 'v2'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('100') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att2 = 'v1', att3 = 'v2'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('100') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2
# Description: [att2 = 'v2', att3 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('010') ; Sequence of instances fp = bitarray('000') ; Quality Measure WRAcc = 0.22222222222222224 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.6666666666666667 ; tp = 1 ; fp = 0 ; TP = 1 ; FP = 2
# Description: [att2 = 'v3', att3 = 'v1'], Target: class = 'yes' ; Sequence of instances tp = bitarray('000') ; Sequence of instances fp = bitarray('001') ; Quality Measure WRAcc = -0.1111111111111111 ; Optimistic Estimate WRAccOptimisticEstimate1 = 0.0 ; tp = 0 ; fp = 1 ; TP = 1 ; FP = 2

# %% [markdown]
# Each of these lines represents a subgroup discovered by the algorithm along with some of its characteristics. If we take the first result as an example, we have the following characteristics:
#
# - The subgroup is described by the pattern `[att1 = 'v1']`.
# - The target is the one we defined initially, i.e., `class = 'yes'`.
# - The quality of the subgroup is measured by the WRAcc measure, which has a value of -0.1111111111111111
# - The optimistic estimate of the subgroup has a value of 0.0
# - The values of tp, fp, TP, and FP are as follows: tp = 0 ; fp = 1 ; TP = 1 ; FP = 2.
#
# These results have been verified in the output file of the VLSD algorithm run on a toy dataset.

# %% [markdown]
# We can also access different statistics about the result:

# %%
print("Selected subgroups: ", model.selected_subgroups) # Number of selected subgroups
print("Unselected subgroups: ", model.unselected_subgroups) # Number of unselected subgroups due to not meeting the minimum quality threshold
print("Visited nodes: ", model.visited_nodes) # Number of nodes (subgroups) visited from the search space
# Out:
# Selected subgroups:  20
# Unselected subgroups:  0
# Visited nodes:  20

# %% [markdown]
# # References

# %% [markdown]
# <a id="1">[1]</a>
# Lopez-Martinez-Carrasco, A., Juarez, J.M., Campos, M., Canovas-Segura, B. VLSD - An Efficient Subgroup Discovery Algorithm Based on Equivalence Classes and Optimistic Estimate. Algorithms 2023, 16, 274. https://doi.org/10.3390/a16060274
