# %% [markdown]
# # Compare Results of Clustering, DFS and VLSD

# %%
import os

# Print the current file path
print("Current file path:", os.path.abspath("SF_Comparison_Results_LR.ipynb"))
# Out:
# Current file path: /home/dionnegantzert/Desktop/master_thesis/Thesis/Experiments/4. Subgroup Fairness LR/SF_Comparison_Results_LR.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
import ptitprince as pt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
clustering_df = pd.read_csv('kmedoids_lr_results.csv')
DFS_df = pd.read_csv('DFS_lr_results.csv')
VLSD_df = pd.read_csv('VLSD_lr_results.csv')

clustering_df = clustering_df.drop_duplicates()
DFS_df = DFS_df.drop_duplicates()
VLSD_df = VLSD_df.drop_duplicates()

clustering_df = clustering_df[clustering_df['description'] != '{}']
DFS_df = DFS_df[DFS_df['description'] != '{}']
VLSD_df = VLSD_df[VLSD_df['description'] != '{}']

clustering_df['model'] = 'Kmedoids'
VLSD_df['model'] = 'VLSD'
DFS_df['model'] = 'DFS'

# colors = ['#ff6d6d', '#c2891c', '#5d9a2e']
# palette = { 'Kmedoids': colors[0], 'VLSD': colors[1], 'DFS': colors[2] }
palette = {'Kmedoids': '#1f77b4', 'VLSD': '#ff7f0e', 'DFS': '#2ca02c'}
combined_df = pd.concat([clustering_df, VLSD_df, DFS_df])

# %% [markdown]
# # Internal Subgroup Fairness

# %% [markdown]
# ### Demographic Parity Difference

# %%
plt.figure(figsize=(10, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['demographic_parity_difference'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Demographic Parity Difference Score')
plt.ylabel('Density')
plt.title('Density Plot of DPD Scores by SD')
plt.legend(title='Model')

# Show the plot
plt.show()

# %% [markdown]
# ### Equalized Odds Difference

# %%
plt.figure(figsize=(10, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['equalized_odds_difference'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Equalized Odds Difference Score')
plt.ylabel('Density')
plt.title('Density Plot of EOD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %% [markdown]
# ## Wrong Disadvantage

# %%
plt.figure(figsize=(10, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['Wrong disadvantage'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Wrong Disadvantage Score')
plt.ylabel('Density')
plt.title('Density Plot of WD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %%
cluster_values =  clustering_df['Wrong disadvantage'].value_counts()
DFS_values =  DFS_df['Wrong disadvantage'].value_counts()
VLSD_values =  VLSD_df['Wrong disadvantage'].value_counts()

print('clustering')
print('min', 'occurence')
print(clustering_df['Wrong disadvantage'].min(), cluster_values[0])
print('mean')
print(clustering_df['Wrong disadvantage'].mean())
print('max', 'occurence')
print(clustering_df['Wrong disadvantage'].max(), list(cluster_values)[-1])
print("\n")

print('DFS')
print('min', 'occurence')
print(DFS_df['Wrong disadvantage'].min(), DFS_values[0])
print('mean')
print(DFS_df['Wrong disadvantage'].mean())
print('max', 'occurence')
print(DFS_df['Wrong disadvantage'].max(), list(DFS_values)[-1])
print("\n")

print('VLSD')
print('min', 'occurence')
print(VLSD_df['Wrong disadvantage'].min(), VLSD_values[0])
print('mean')
print(VLSD_df['Wrong disadvantage'].mean())
print('max', 'occurence')
print(VLSD_df['Wrong disadvantage'].max(), list(VLSD_values)[-1])
print("\n")
# Out:
# clustering
# min occurence
# 0.0 52
# mean
# 0.022721
# max occurence
# 0.1867 1
#
#
# DFS
# min occurence
# 0.0 51
# mean
# 0.013117
# max occurence
# 0.0642 1
#
#
# VLSD
# min occurence
# 0.0 60
# mean
# 0.010821
# max occurence
# 0.0642 1

# %% [markdown]
# # External Subgroup Fairness

# %%
fig, axes = plt.subplots(2, 2, figsize=(17, 9))

# List of metrics and their respective subplot indices
metrics = [
    ('weighted_dpd_subgroup', 'Weighted Demographic Parity Difference Subgroup Fairness Score', axes[0, 0]),
    ('weighted_eod_subgroup', 'Weighted Equalized Odds Difference Subgroup Fairness Score', axes[0, 1]),
    ('weighted_tp_subgroup', 'Weighted True Positive Difference Score', axes[1, 0]),
    ('weighted_fp_subgroup', 'Weighted False Positive Difference Score', axes[1, 1])
]

# Plot each metric in the corresponding subplot
for metric, xlabel, ax in metrics:
    for model in combined_df['model'].unique():
        subset = combined_df[combined_df['model'] == model]
        sns.kdeplot(subset[metric], label=model, color=palette[model], fill=True, ax=ax, alpha=.2)
#         ax.axvline(x=subset[metric].mean(), color=palette[model], linestyle='--')
    ax.axvline(x=0, color='black', linestyle='--')
    
    ax.set_xlabel(xlabel)
    ax.set_ylabel('Density')
#     ax.set_xlim(-0.05, 0.1)
#     ax.set_ylim(0, 100)
    ax.set_title(f'Density Plot of {xlabel} by Model')
    ax.legend(title='Model')

# Adjust layout for better spacing
fig.tight_layout()
plt.show()

# %%
for feature in ['weighted_dpd_subgroup', 'weighted_eod_subgroup', 'weighted_tp_subgroup','weighted_fp_subgroup']:
    print(feature)
    
    c_unique_values = clustering_df[feature].unique()
    d_unique_values = DFS_df[feature].unique()
    v_unique_values = VLSD_df[feature].unique()
    c_sorted_unique_values = sorted(c_unique_values)
    d_sorted_unique_values = sorted(d_unique_values)
    v_sorted_unique_values = sorted(v_unique_values)
    cluster_values = clustering_df[feature].value_counts().loc[c_sorted_unique_values]
    DFS_values = DFS_df[feature].value_counts().loc[d_sorted_unique_values]
    VLSD_values = VLSD_df[feature].value_counts().loc[v_sorted_unique_values]
    
    print('clustering')
    print('min', 'occurence')
    print(clustering_df[feature].min(), list(cluster_values)[0])
    print('mean')
    print(clustering_df[feature].mean())
    print('max', 'occurence')
    print(clustering_df[feature].max(), list(cluster_values)[-1])
    print("\n")

    print('DFS')
    print('min', 'occurence')
    print(DFS_df[feature].min(), list(DFS_values)[0])
    print('mean')
    print(DFS_df[feature].mean())
    print('max', 'occurence')
    print(DFS_df[feature].max(), list(DFS_values)[-1])
    print("\n")

    print('VLSD')
    print('min', 'occurence')
    print(VLSD_df[feature].min(), list(VLSD_values)[0])
    print('mean')
    print(VLSD_df[feature].mean())
    print('max', 'occurence')
    print(VLSD_df[feature].max(), list(VLSD_values)[-1])
    print("\n", "\n", "\n")
# Out:
# weighted_dpd_subgroup
# clustering
# min occurence
# 0.0004 1
# mean
# 0.015468000000000003
# max occurence
# 0.078 1
#
#
# DFS
# min occurence
# 0.0053 1
# mean
# 0.031736
# max occurence
# 0.078 1
#
#
# VLSD
# min occurence
# 0.0085 1
# mean
# 0.034669
# max occurence
# 0.078 1
#
#
#
#
# weighted_eod_subgroup
# clustering
# min occurence
# 0.0002 1
# mean
# 0.007613000000000001
# max occurence
# 0.0382 1
#
#
# DFS
# min occurence
# 0.0032 2
# mean
# 0.015137000000000003
# max occurence
# 0.0382 1
#
#
# VLSD
# min occurence
# 0.0042 1
# mean
# 0.016667
# max occurence
# 0.0382 1
#
#
#
#
# weighted_tp_subgroup
# clustering
# min occurence
# -0.0382 1
# mean
# -0.006820999999999999
# max occurence
# 0.007 1
#
#
# DFS
# min occurence
# -0.0382 1
# mean
# -0.015037
# max occurence
# -0.0031 1
#
#
# VLSD
# min occurence
# -0.0382 1
# mean
# -0.016579
# max occurence
# -0.0042 1
#
#
#
#
# weighted_fp_subgroup
# clustering
# min occurence
# -0.0257 1
# mean
# -0.004884
# max occurence
# 0.0024 1
#
#
# DFS
# min occurence
# -0.0293 1
# mean
# -0.008347
# max occurence
# -0.0008 2
#
#
# VLSD
# min occurence
# -0.0293 1
# mean
# -0.008391000000000001
# max occurence
# -0.0008 2

# %% [markdown]
# # Junk

# %%
clustering_df['demographic_parity_subgroup'].max()
# Out:
# 0.1984

# %%
plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['demographic_parity_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Demographic Parity Score')
plt.ylabel('Density')
plt.title('Density Plot of DPD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %%
# colors = ['#ff6d6d', '#c2891c', '#5d9a2e']
# palette = { 'Kmedoids': colors[0], 'VLSD': colors[1], 'DFS': colors[2]}

plt.figure(figsize=(10, 6))
sns.boxplot(y='model', x='demographic_parity_subgroup', data=combined_df, palette=palette, hue='model')
plt.axvline(x=0, color='black', linestyle='--')

plt.xlabel('Model')
plt.ylabel('Demographic Parity Score')
plt.title('Distribution of DPD Scores by Model')

plt.show()

# %%
plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['weighted_dpd_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Weighted Demographic Parity Difference Subgroup Fairness Score')
plt.ylabel('Density')
plt.title('Density Plot of Weighted DPD Subgroup Fairness Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %% [markdown]
# ### Equalized Odds Difference

# %%
plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['equalized_odds_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Equalized Odds Difference Score')
plt.ylabel('Density')
plt.title('Density Plot of EOD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %%
# colors = ['#ff6d6d', '#c2891c', '#5d9a2e']
# palette = { 'Kmedoids': colors[0], 'VLSD': colors[1], 'DFS': colors[2]}

plt.figure(figsize=(10, 6))
sns.boxplot(y='model', x='equalized_odds_subgroup', data=combined_df, palette=palette, hue='model')
plt.axvline(x=0, color='black', linestyle='--')

plt.xlabel('Model')
plt.ylabel('Equalized Odds Difference Score')
plt.title('Distribution of EOD Scores by Model')

plt.show()

# %%
plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['weighted_eod_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Weighted Equalized Odds Difference Subgroup Fairness Score')
plt.ylabel('Density')
plt.title('Density Plot of Weighted EOD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %% [markdown]
# ### True Positive Difference

# %%
plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['true_positive_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('True Positive Difference Score')
plt.ylabel('Density')
plt.title('Density Plot of FPD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['weighted_tp_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Weighted True Positive Difference Score')
plt.ylabel('Density')
plt.title('Density Plot of Weighted TPD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %% [markdown]
# ### False Positive Difference

# %%
plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['weighted_fp_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Weighted False Positive Difference Score')
plt.ylabel('Density')
plt.title('Density Plot of Weighted FPD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %%
# colors = ['#00859a', '#42ac60', '#ffa600']
# colors = ['#ff6d6d', '#c2891c', '#5d9a2e']

# palette = { 'Kmedoids': colors[0], 'VLSD': colors[1], 'DFS': colors[2] }

plt.figure(figsize=(10, 6))
sns.boxplot(y='model', x='false_positive_subgroup', data=combined_df, palette=palette)


plt.axvline(x=0, color='black', linestyle='--')
# Add labels and title
plt.xlabel('Model')
plt.ylabel('Equalized Odds Difference Score')
plt.title('Distribution of EOD Scores by Model')

# Show the plot
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Other stuff

# %%
# # Create the violin plot
# import seaborn as sns
# # Add a column to identify the model
clustering_df['model'] = 'Kmedoids'
VLSD_df['model'] = 'VLSD'
DFS_df['model'] = 'DFS'

# colors = ['#ff6d6d', '#c2891c', '#5d9a2e']

# palette = { 'Kmedoids': colors[0], 'VLSD': colors[1], 'DFS': colors[2] }

# # Combine all DataFrames
combined_df = pd.concat([clustering_df, VLSD_df, DFS_df])

# Create the violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='model', y='demographic_parity_subgroup', data=combined_df, inner="quartile", palette=palette)

# Add labels and title
plt.xlabel('Model')
plt.ylabel('Demographic Parity Score')
plt.title('Distribution of Demographic Parity Scores by Model')

# Show the plot
plt.show()

# %%
max_x = 28

y1 = np.abs(clustering_df['demographic_parity_subgroup'][:max_x])
y2 = np.abs(VLSD_df['demographic_parity_subgroup'][:max_x])
y3 = np.abs(DFS_df['demographic_parity_subgroup'][:max_x])
# y4 = np.abs(data_clustering['statistical_parity_subgroup'][:max_x])

x = np.arange(max_x)  # x values
width = 0.2  # width of the bars

fig, ax = plt.subplots(figsize=(20,5))
ax.bar(x - width, y1, width, label='Clustering')
ax.bar(x,y2 , width, label='VLSD')
ax.bar(x + width, y3, width, label='DFS')
# ax.bar(x + 2*width, y4, width, label='Data')

# Add labels, title, and legend
ax.set_xlabel('Subgroups')
ax.set_ylabel('Demographic Parity Subgroup Fairness')
ax.set_title('DP Subgroup Fairness for each method')
ax.legend()

# Show the plot
plt.show()

# %%
# y1 = np.abs(clustering_df['statistical_parity_subgroup'][:max_x])
# y2 = np.abs(VLSD_df['statistical_parity_subgroup'][:max_x])
# y3 = np.abs(DFS_df['statistical_parity_subgroup'][:max_x])

y1 = clustering_df['demographic_parity_subgroup'][:max_x]
y2 = VLSD_df['demographic_parity_subgroup'][:max_x]
y3 = DFS_df['demographic_parity_subgroup'][:max_x]
# y4 = data_clustering['statistical_parity_subgroup'][:max_x]

# y1_sorted = np.abs(clustering_df['statistical_parity_subgroup'][:max_x].sort_values(ascending=True))
# y2_sorted = np.abs(VLSD_df['statistical_parity_subgroup'][:max_x].sort_values(ascending=True))
# y3_sorted = np.abs(DFS_df['statistical_parity_subgroup'][:max_x].sort_values(ascending=True))

y1_sorted = clustering_df['demographic_parity_subgroup'][:max_x].sort_values(ascending=True)
y2_sorted = VLSD_df['demographic_parity_subgroup'][:max_x].sort_values(ascending=True)
y3_sorted = DFS_df['demographic_parity_subgroup'][:max_x].sort_values(ascending=True)
# y4_sorted = data_clustering['statistical_parity_subgroup'][:max_x].sort_values(ascending=True)


# plt.axhline(y=np.mean(y2), color='red', linestyle='--')

x = np.arange(max_x)  # x values

fig, ax = plt.subplots(figsize=(15,10))
ax.plot(x, list(y1_sorted), label='Clustering')
ax.plot(x, list(y2_sorted), label='VLSD')
ax.plot(x, list(y3_sorted), label='DFS')
# ax.plot(x, list(y4_sorted), label='Data')

ax.axhline(y=np.mean(y1), color='blue', linestyle='--')
ax.axhline(y=np.mean(y2), color='orange', linestyle='--')
ax.axhline(y=np.mean(y3), color='green', linestyle='--')
# ax.axhline(y=np.mean(y4), color='red', linestyle='--')

# Add labels, title, and legend
ax.set_xlabel('Subgroups')
ax.set_ylabel('Demographic Parity Subgroup Fairness')
ax.set_title('DP Subgroup Fairness for each method')
ax.legend()

# Show the plot
plt.show()

# %%
# y1 = np.abs(clustering_df['statistical_parity_subgroup'][:max_x])
# y2 = np.abs(VLSD_df['statistical_parity_subgroup'][:max_x])
# y3 = np.abs(DFS_df['statistical_parity_subgroup'][:max_x])

y1 = clustering_df['equalized_odds_subgroup'][:max_x]
y2 = VLSD_df['equalized_odds_subgroup'][:max_x]
y3 = DFS_df['equalized_odds_subgroup'][:max_x]
# y4 = data_clustering['statistical_parity_subgroup'][:max_x]

# y1_sorted = np.abs(clustering_df['statistical_parity_subgroup'][:max_x].sort_values(ascending=True))
# y2_sorted = np.abs(VLSD_df['statistical_parity_subgroup'][:max_x].sort_values(ascending=True))
# y3_sorted = np.abs(DFS_df['statistical_parity_subgroup'][:max_x].sort_values(ascending=True))

y1_sorted = clustering_df['equalized_odds_subgroup'][:max_x].sort_values(ascending=True)
y2_sorted = VLSD_df['equalized_odds_subgroup'][:max_x].sort_values(ascending=True)
y3_sorted = DFS_df['equalized_odds_subgroup'][:max_x].sort_values(ascending=True)
# y4_sorted = data_clustering['statistical_parity_subgroup'][:max_x].sort_values(ascending=True)


# plt.axhline(y=np.mean(y2), color='red', linestyle='--')

x = np.arange(max_x)  # x values

fig, ax = plt.subplots(figsize=(15,10))
ax.plot(x, list(y1_sorted), label='Clustering')
ax.plot(x, list(y2_sorted), label='VLSD')
ax.plot(x, list(y3_sorted), label='DFS')
# ax.plot(x, list(y4_sorted), label='Data')

ax.axhline(y=np.mean(y1), color='blue', linestyle='--')
ax.axhline(y=np.mean(y2), color='orange', linestyle='--')
ax.axhline(y=np.mean(y3), color='green', linestyle='--')
# ax.axhline(y=np.mean(y4), color='red', linestyle='--')

# Add labels, title, and legend
ax.set_xlabel('Subgroups')
ax.set_ylabel('Equalized Odds Difference Subgroup Fairness')
ax.set_title('EOD Subgroup Fairness for each method')
ax.legend()

# Show the plot
plt.show()

# %%
line_plot('weighted_eod_subgroup')

# %%
cols = ['Accuracy', 'Wrong disadvantage', 'Recall',
       'sensitivity', 'specificity', 'piatetsky_shapiro', 'WRAcc_score',
       'WRAcc_score_optimistic', 'demographic_parity_difference',
       'equalized_odds_difference', 'demographic_parity_subgroup',
       'equalized_odds_subgroup', 'true_positive_subgroup',
       'false_positive_subgroup', 'weighted_dpd_subgroup',
       'weighted_fp_subgroup', 'model']

for feature in cols:
    y = clustering_df[feature].sort_values(ascending=False)
    x = np.arange(0, len(clustering_df[feature]))
    plt.scatter(x, y)
    plt.title(feature)
    plt.show()

# %%
plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['weighted_dpd_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Weighted Demographic Parity Difference Subgroup Fairness Score')
plt.ylabel('Density')
plt.title('Density Plot of Weighted DPD Subgroup Fairness Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()


plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['weighted_eod_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Weighted Equalized Odds Difference Subgroup Fairness Score')
plt.ylabel('Density')
plt.title('Density Plot of Weighted EOD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()



plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['weighted_tp_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Weighted True Positive Difference Score')
plt.ylabel('Density')
plt.title('Density Plot of Weighted TPD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

plt.figure(figsize=(15, 6))
for model in combined_df['model'].unique():
    subset = combined_df[combined_df['model'] == model]
    sns.kdeplot(subset['weighted_fp_subgroup'], label=model, color=palette[model], fill=True)

# Add a vertical line at x = 0
plt.axvline(x=0, color='black', linestyle='--')

# Add labels and title
plt.xlabel('Weighted False Positive Difference Score')
plt.ylabel('Density')
plt.title('Density Plot of Weighted FPD Scores by Model')
plt.legend(title='Model')

# Show the plot
plt.show()

# %%
def half_violin_scatter(feature):
    palette = {'Kmedoids': '#1f77b4', 'VLSD': '#ff7f0e', 'DFS': '#2ca02c'}
    models = combined_df['model'].unique()
    colors = [palette[model] for model in models]

    fig, ax = plt.subplots(figsize=(15, 6))

    pt.half_violinplot(
        x=feature, y="model", palette=colors, 
        inner=None, data=combined_df, width=1, ax=ax
    )
    for i, model in enumerate(models):
        subset = combined_df[combined_df['model'] == model]
    #     sns.half_violinplot(data=subset, x='demographic_parity_difference', y='model', palette=[colors[i]], inner=None, ax=ax, orient='h', cut=0, linewidth=1)

        # Jitter the values on the vertical axis
        y = np.full(len(subset), i) + np.random.uniform(-0.1, 0.1, len(subset))

        # Select the values of the horizontal axis
        x = subset[feature]

        # Add the scatter plot
        ax.scatter(x, y, color=colors[i], alpha=0.6)

    # Add a vertical line at x = 0
    plt.axvline(x=0, color='black', linestyle='--')

    # Add labels and title
    plt.xlabel(feature + ' score')
    plt.ylabel('Model')
    plt.title('Half Violin Plot of ' + feature + ' Scores by Model')

    # Show the plot
    plt.show()
    
half_violin_scatter('demographic_parity_difference')
